# %%
# !jupyter nbconvert --to html /content/Decision_tree.ipynb
# Out:
# [NbConvertApp] Converting notebook /content/Decision_tree.ipynb to html
# [NbConvertApp] Writing 627952 bytes to /content/Decision_tree.html

# %%
# !jupyter nbconvert --to html /content/Bayesian_Classification.ipynb
# Out:
# [NbConvertApp] Converting notebook /content/Bayesian_Classification.ipynb to html
# [NbConvertApp] Writing 605997 bytes to /content/Bayesian_Classification.html

# %%
# !jupyter nbconvert --to html /content/SupportVectorMachine.ipynb
# Out:
# [NbConvertApp] Converting notebook /content/SupportVectorMachine.ipynb to html
# [NbConvertApp] Writing 605858 bytes to /content/SupportVectorMachine.html

# %%
# !jupyter nbconvert --to html /content/K_means.ipynb
# Out:
# [NbConvertApp] Converting notebook /content/K_means.ipynb to html
# [NbConvertApp] Writing 608474 bytes to /content/K_means.html

# %%
# !jupyter nbconvert --to html /content/Data_preprocessing_and_cleaning.ipynb
# Out:
# [NbConvertApp] Converting notebook /content/Data_preprocessing_and_cleaning.ipynb to html
# [NbConvertApp] Writing 631204 bytes to /content/Data_preprocessing_and_cleaning.html

# %%
# !jupyter nbconvert --to html /content/Data_preprocessing_and_cleaning.ipynb
# Out:
# [NbConvertApp] Converting notebook /content/Data_preprocessing_and_cleaning.ipynb to html
# [NbConvertApp] Writing 631334 bytes to /content/Data_preprocessing_and_cleaning.html

# %%
# !jupyter nbconvert --to html /content/Centroid.ipynb
# Out:
# [NbConvertApp] Converting notebook /content/Centroid.ipynb to html
# [NbConvertApp] Writing 748723 bytes to /content/Centroid.html

# %%
# !jupyter nbconvert --to html /content/mini_batch.ipynb
# Out:
# [NbConvertApp] Converting notebook /content/mini_batch.ipynb to html
# [NbConvertApp] Writing 748493 bytes to /content/mini_batch.html

# %%
# !jupyter nbconvert --to html /content/Agglomerative.ipynb
# Out:
# [NbConvertApp] Converting notebook /content/Agglomerative.ipynb to html
# [NbConvertApp] Writing 770281 bytes to /content/Agglomerative.html

# %%
# !jupyter nbconvert --to html /content/DBSCAN.ipynb
# Out:
# [NbConvertApp] Converting notebook /content/DBSCAN.ipynb to html
# [NbConvertApp] Writing 629656 bytes to /content/DBSCAN.html

# %%
# !jupyter nbconvert --to html /content/Decision_tree (1).ipynb
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `('
# /bin/bash: -c: line 0: `jupyter nbconvert --to html /content/Decision_tree (1).ipynb'

# %%
# !jupyter nbconvert --to html /content/Decision_tree.ipynb
# Out:
# [NbConvertApp] Converting notebook /content/Decision_tree.ipynb to html
# [NbConvertApp] Writing 626631 bytes to /content/Decision_tree.html

# %%
# !jupyter nbconvert --to html /content/Bayesian_Classification.ipynb
# Out:
# [NbConvertApp] Converting notebook /content/Bayesian_Classification.ipynb to html
# [NbConvertApp] Writing 606152 bytes to /content/Bayesian_Classification.html

# %%
# !jupyter nbconvert --to html /content/SupportVectorMachine.ipynb
# Out:
# [NbConvertApp] Converting notebook /content/SupportVectorMachine.ipynb to html
# [NbConvertApp] Writing 606041 bytes to /content/SupportVectorMachine.html

# %%
# !jupyter nbconvert --to html /content/K_means.ipynb
# Out:
# [NbConvertApp] Converting notebook /content/K_means.ipynb to html
# [NbConvertApp] Writing 608597 bytes to /content/K_means.html

# %%
# !jupyter nbconvert --to html /content/Apriori_Algorithm.ipynb
# Out:
# [NbConvertApp] Converting notebook /content/Apriori_Algorithm.ipynb to html
# [NbConvertApp] Writing 604336 bytes to /content/Apriori_Algorithm.html

# %%
# !jupyter nbconvert --to html /content/K_medoids.ipynb
# Out:
# [NbConvertApp] Converting notebook /content/K_medoids.ipynb to html
# [NbConvertApp] Writing 640403 bytes to /content/K_medoids.html

# %%
# !jupyter nbconvert --to html /content/FP_Growth1.ipynb
# Out:
# [NbConvertApp] Converting notebook /content/FP_Growth1.ipynb to html
# [NbConvertApp] Writing 598356 bytes to /content/FP_Growth1.html
