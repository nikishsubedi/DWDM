# %%
# !wget https://raw.githubusercontent.com/prakriti1221/Crop/main/Crop_recommendation.csv
# Out:
# --2023-04-11 05:04:10--  https://raw.githubusercontent.com/prakriti1221/Crop/main/Crop_recommendation.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 150034 (147K) [text/plain]
# Saving to: ‘Crop_recommendation.csv’
#
# Crop_recommendation 100%[===================>] 146.52K  --.-KB/s    in 0.03s
#
# 2023-04-11 05:04:11 (5.32 MB/s) - ‘Crop_recommendation.csv’ saved [150034/150034]
